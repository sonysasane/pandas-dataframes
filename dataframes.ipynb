# %% [markdown]
# DATAFRAMES

# %%
import numpy as np
import pandas as pd

# %%
data = np.random.randn(5,3)

# %%
data
# Out:
# array([[-0.6418069 ,  0.81857584, -0.97971445],
#        [ 0.70964256, -0.32706501,  0.45966591],
#        [-0.44807015,  0.09744396,  0.87396589],
#        [-0.36483621, -0.83894994,  0.68047738],
#        [-0.42893393, -0.64041267, -0.18274047]])

# %%
pd.DataFrame(data)
# Out:
#           0         1         2
# 0 -0.641807  0.818576 -0.979714
# 1  0.709643 -0.327065  0.459666
# 2 -0.448070  0.097444  0.873966
# 3 -0.364836 -0.838950  0.680477
# 4 -0.428934 -0.640413 -0.182740

# %%
pd.DataFrame(data, columns = ['a','b','c'])
# Out:
#           a         b         c
# 0 -0.641807  0.818576 -0.979714
# 1  0.709643 -0.327065  0.459666
# 2 -0.448070  0.097444  0.873966
# 3 -0.364836 -0.838950  0.680477
# 4 -0.428934 -0.640413 -0.182740

# %%
pd.read_csv("adult.data.csv", header = None)
# Out:
#           0   1      2     3             4   5       6   7   \
# 0          1  39   2174     0     Bachelors  13   77516  40
# 1          2  50      0     0     Bachelors  13   83311  13
# 2          3  38      0     0       HS-grad   9  215646  40
# 3          4  53      0     0          11th   7  234721  40
# 4          5  28      0     0     Bachelors  13  338409  40
# 5          6  37      0     0       Masters  14  284582  40
# 6          7  49      0     0           9th   5  160187  16
# 7          8  52      0     0       HS-grad   9  209642  45
# 8          9  31  14084     0       Masters  14   45781  50
# 9         10  42   5178     0     Bachelors  13  159449  40
# 10        11  37      0     0  Some-college  10  280464  80
# 11        12  30      0     0     Bachelors  13  141297  40
# 12        13  23      0     0     Bachelors  13  122272  30
# 13        14  32      0     0    Assoc-acdm  12  205019  50
# 14        15  40      0     0     Assoc-voc  11  121772  40
# ...
